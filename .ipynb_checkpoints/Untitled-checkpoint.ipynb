# %%
import os
for root, dirs, files in os.walk("/"):
    for file in files:
        if file.endswith(".cpp"):
             print(os.path.join(root, file))
# Out:
# /boot/grub/gfxblacklist.txt
# /var/lib/gdm3/.cache/tracker/no-need-mtime-check.txt
# /var/lib/gdm3/.cache/tracker/db-version.txt
# /var/lib/gdm3/.cache/tracker/db-locale.txt
# /var/lib/gdm3/.cache/tracker/first-index.txt
# /var/lib/gdm3/.cache/tracker/parser-version.txt
# /var/lib/gdm3/.cache/tracker/last-crawl.txt
# /var/lib/gdm3/.cache/tracker/locale-for-miner-apps.txt
# /var/cache/dictionaries-common/ispell-dicts-list.txt
# /opt/sublime_text/changelog.txt
# /host/$Recycle.Bin/S-1-5-21-782586294-369645402-4186742806-1001/$II52LA2.txt
# /host/$Recycle.Bin/S-1-5-21-782586294-369645402-4186742806-1001/$RI52LA2.txt
# /host/$Recycle.Bin/S-1-5-21-782586294-369645402-4186742806-1001/$RY171ES/Log.txt
# /host/$WINDOWS.~BT/Sources/hwcompat.txt
# /host/$WINDOWS.~BT/Sources/hwcompatPE.txt
# /host/$WINDOWS.~BT/Sources/hwexclude.txt
# /host/$WINDOWS.~BT/Sources/hwexcludePE.txt
# /host/$WINDOWS.~BT/Sources/idwbinfo.txt
# /host/$WINDOWS.~BT/Sources/en-us/erofflps.txt
# ...
